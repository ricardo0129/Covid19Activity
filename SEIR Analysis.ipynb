# %%
from plot import *
#get data from 08-08-2020 - 02-24-2021 from whole U.S.
data = get_data("08-08-2020","02-24-2021")
#Add the data to the graph using the label U.S.
add_data(data,"U.S.")
#Display all the data
show_graph()

# %%
from plot import *
#Plot data from 08-08-2020 - 02-24-2021 from Florida only 
data = get_data("11-01-2021","02-20-2022","Florida")
add_data(data,"Florida")
show_graph()

# %%
from plot import *
#Plot data from 08-08-2020 - 02-24-2021 from Florida only 
data1 = get_data("11-01-2021","02-20-2022","Florida")
adjust_7day_avg(data1)
add_data(data1,"Florida")

data2 = get_data("11-01-2021","02-20-2022","California")
adjust_7day_avg(data2)
add_data(data2,"California")
show_graph()
